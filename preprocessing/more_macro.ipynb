# %% [markdown]
# # Merge All Datasets in `more_macro`
#
# This notebook loads every CSV in `additional_dataset/more_macro/`, creates
# `approval_year` and `approval_month` from each series date, and outer-merges all
# series into a single monthly table.

# %%
from pathlib import Path
import pandas as pd

pd.set_option('display.max_columns', 200)

PROJECT_ROOT = Path('/Users/yangmar/Desktop/MS&E 246/Project')
MACRO_DIR = PROJECT_ROOT / 'additional_dataset' / 'more_macro'
OUT_PATH = MACRO_DIR / 'more_macro_merged_monthly.csv'

# Preferred output column names by FRED series code.
FRIENDLY_NAME_MAP = {
    'BUSLOANS': 'commercial_bank_loans_leases_billions',
    'TOTALSL': 'consumer_credit_outstanding_millions',
    'PSAVERT': 'personal_savings_rate_pct',
    'UMCSENT': 'consumer_sentiment_index',
    'CORBLACBS': 'business_loan_chargeoff_rate_pct',
    'DRALACBS': 'all_loan_delinquency_rate_pct',
    'TDSP': 'household_debt_service_ratio_pct',
    'CPIAUCSL': 'cpi_u_seasonality_adjusted',
    'CPILFESL': 'core_cpi_excl._food_energy'
}

print('Macro folder:', MACRO_DIR)
print('CSV count:', len(list(MACRO_DIR.glob('*.csv'))))
# Out:
# Macro folder: /Users/yangmar/Desktop/MS&E 246/Project/additional_dataset/more_macro
# CSV count: 8

# %%
# Load and normalize each CSV to: approval_year, approval_month, <series>
series_tables = []
coverage = []

for csv_path in sorted(MACRO_DIR.glob('*.csv')):
    df = pd.read_csv(csv_path)
    df.columns = [str(c).replace('\ufeff', '').strip() for c in df.columns]

    date_col = next((c for c in df.columns if c.lower() in ('observation_date', 'date')), None)
    if date_col is None:
        raise ValueError(f'{csv_path.name}: no date column found. Columns={list(df.columns)}')

    value_cols = [c for c in df.columns if c != date_col]
    if len(value_cols) != 1:
        raise ValueError(f'{csv_path.name}: expected exactly one value column, got {value_cols}')

    raw_value_col = value_cols[0]
    friendly_col = FRIENDLY_NAME_MAP.get(raw_value_col)

    if not friendly_col:
        # Fallback: use file stem if a code is not in the map
        friendly_col = csv_path.stem.lower().replace('-', '_').replace(' ', '_')

    x = pd.DataFrame({
        'date': pd.to_datetime(df[date_col], errors='coerce'),
        friendly_col: pd.to_numeric(df[raw_value_col], errors='coerce')
    }).dropna(subset=['date', friendly_col])

    x['approval_year'] = x['date'].dt.year.astype('int64')
    x['approval_month'] = x['date'].dt.month.astype('int64')

    # If series has >1 point in a month (e.g., daily/weekly), collapse to monthly mean.
    x = (
        x.groupby(['approval_year', 'approval_month'], as_index=False)[friendly_col]
        .mean()
        .sort_values(['approval_year', 'approval_month'])
    )

    series_tables.append(x)
    coverage.append((csv_path.name, raw_value_col, friendly_col, x['approval_year'].min(), x['approval_month'].min(), x['approval_year'].max(), x['approval_month'].max(), len(x)))

coverage_df = pd.DataFrame(
    coverage,
    columns=['file', 'raw_series_col', 'friendly_col', 'start_year', 'start_month', 'end_year', 'end_month', 'rows']
)
display(coverage_df)
# Out:
#                                     file raw_series_col  \
# 0         CPI-U_seasonality_adjusted.csv       CPIAUCSL
# 1  Charge-off_rate_on_business_loans.csv      CORBLACBS
# 2   Commercial_bank_loans_and_leases.csv       BUSLOANS
# 3        Consumer_credit_outstanding.csv        TOTALSL
# 4         Core_CPI_excl._food_energy.csv       CPILFESL
# 5       Delinquency_rate_on_all_loan.csv       DRALACBS
# 6              Personal_savings_rate.csv        PSAVERT
# 7       UMichigan_Consumer_Sentiment.csv        UMCSENT
#
#                             friendly_col  start_year  start_month  end_year  \
# 0             cpi_u_seasonality_adjusted        1990            1      2014
# 1       business_loan_chargeoff_rate_pct        1990            1      2014
# 2  commercial_bank_loans_leases_billions        1990            1      2014
# 3   consumer_credit_outstanding_millions        1990            1      2014
# 4             core_cpi_excl._food_energy        1990            1      2014
# 5          all_loan_delinquency_rate_pct        1990            1      2014
# 6              personal_savings_rate_pct        1990            1      2014
# 7               consumer_sentiment_index        1990            1      2014
#
#    end_month  rows
# 0         12   300
# 1         10   100
# 2         12   300
# 3         12   300
# 4         12   300
# 5         10   100
# 6         12   300
# 7         12   300

# %%
series_tables
# Out:
# [     approval_year  approval_month  cpi_u_seasonality_adjusted
#  0             1990               1                     127.500
#  1             1990               2                     128.000
#  2             1990               3                     128.600
#  3             1990               4                     128.900
#  4             1990               5                     129.100
#  ..             ...             ...                         ...
#  295           2014               8                     237.460
#  296           2014               9                     237.477
#  297           2014              10                     237.430
#  298           2014              11                     236.983
#  299           2014              12                     236.252
#
#  [300 rows x 3 columns],
#      approval_year  approval_month  business_loan_chargeoff_rate_pct
#  0            1990               1                              1.41
#  1            1990               4                              1.43
#  2            1990               7                              1.28
#  3            1990              10                              1.30
#  4            1991               1                              1.48
#  ..            ...             ...                               ...
#  95           2013              10                              0.25
#  96           2014               1                              0.23
#  97           2014               4                              0.21
#  98           2014               7                              0.20
#  99           2014              10                              0.22
#
#  [100 rows x 3 columns],
#       approval_year  approval_month  commercial_bank_loans_leases_billions
#  0             1990               1                               635.7875
#  1             1990               2                               636.5317
#  2             1990               3                               638.2437
#  3             1990               4                               640.9802
#  4             1990               5                               639.8110
#  ..             ...             ...                                    ...
#  295           2014               8                              1711.7561
#  296           2014               9                              1725.7351
#  297           2014              10                              1730.8096
#  298           2014              11                              1751.6656
#  299           2014              12                              1773.1780
#
#  [300 rows x 3 columns],
#       approval_year  approval_month  consumer_credit_outstanding_millions
#  0             1990               1                             797714.86
#  1             1990               2                             798773.19
#  2             1990               3                             798748.09
#  3             1990               4                             798747.01
#  4             1990               5                             799751.03
#  ..             ...             ...                                   ...
#  295           2014               8                            3248721.35
#  296           2014               9                            3265101.43
#  297           2014              10                            3275438.44
#  298           2014              11                            3283048.38
#  299           2014              12                            3309539.83
#
#  [300 rows x 3 columns],
#       approval_year  approval_month  core_cpi_excl._food_energy
#  0             1990               1                     132.100
#  1             1990               2                     132.700
#  2             1990               3                     133.500
#  3             1990               4                     134.000
#  4             1990               5                     134.400
#  ..             ...             ...                         ...
#  295           2014               8                     238.405
#  296           2014               9                     238.786
#  297           2014              10                     239.191
#  298           2014              11                     239.458
#  299           2014              12                     239.584
#
#  [300 rows x 3 columns],
#      approval_year  approval_month  all_loan_delinquency_rate_pct
#  0            1990               1                           5.03
#  1            1990               4                           5.08
#  2            1990               7                           5.38
#  3            1990              10                           5.99
#  4            1991               1                           6.13
#  ..            ...             ...                            ...
#  95           2013              10                           3.52
#  96           2014               1                           3.31
#  97           2014               4                           3.08
#  98           2014               7                           2.90
#  99           2014              10                           2.70
#
#  [100 rows x 3 columns],
#       approval_year  approval_month  personal_savings_rate_pct
#  0             1990               1                        7.9
#  1             1990               2                        8.5
#  2             1990               3                        8.3
#  3             1990               4                        8.7
#  4             1990               5                        8.7
#  ..             ...             ...                        ...
#  295           2014               8                        5.3
#  296           2014               9                        5.5
#  297           2014              10                        5.4
#  298           2014              11                        5.6
#  299           2014              12                        6.0
#
#  [300 rows x 3 columns],
#       approval_year  approval_month  consumer_sentiment_index
#  0             1990               1                      93.0
#  1             1990               2                      89.5
#  2             1990               3                      91.3
#  3             1990               4                      93.9
#  4             1990               5                      90.6
#  ..             ...             ...                       ...
#  295           2014               8                      82.5
#  296           2014               9                      84.6
#  297           2014              10                      86.9
#  298           2014              11                      88.8
#  299           2014              12                      93.6
#
#  [300 rows x 3 columns]]

# %%
# Outer-merge all datasets on approval_year + approval_month
merged = None
for t in series_tables:
    if merged is None:
        merged = t.copy()
    else:
        merged = merged.merge(t, on=['approval_year', 'approval_month'], how='outer')

merged = merged.sort_values(['approval_year', 'approval_month']).reset_index(drop=True)

print('Merged shape:', merged.shape)
print('Columns:', merged.columns.tolist())
merged.tail(12)
# Out:
# Merged shape: (300, 10)
# Columns: ['approval_year', 'approval_month', 'cpi_u_seasonality_adjusted', 'business_loan_chargeoff_rate_pct', 'commercial_bank_loans_leases_billions', 'consumer_credit_outstanding_millions', 'core_cpi_excl._food_energy', 'all_loan_delinquency_rate_pct', 'personal_savings_rate_pct', 'consumer_sentiment_index']
#      approval_year  approval_month  cpi_u_seasonality_adjusted  \
# 288           2014               1                     235.288
# 289           2014               2                     235.547
# 290           2014               3                     236.028
# 291           2014               4                     236.468
# 292           2014               5                     236.918
# 293           2014               6                     237.231
# 294           2014               7                     237.498
# 295           2014               8                     237.460
# 296           2014               9                     237.477
# 297           2014              10                     237.430
# 298           2014              11                     236.983
# 299           2014              12                     236.252
#
#      business_loan_chargeoff_rate_pct  commercial_bank_loans_leases_billions  \
# 288                              0.23                              1586.7954
# 289                               NaN                              1619.7096
# 290                               NaN                              1633.3176
# 291                              0.21                              1651.1911
# 292                               NaN                              1663.6926
# 293                               NaN                              1676.8043
# 294                              0.20                              1694.9147
# 295                               NaN                              1711.7561
# 296                               NaN                              1725.7351
# 297                              0.22                              1730.8096
# 298                               NaN                              1751.6656
# 299                               NaN                              1773.1780
#
#      consumer_credit_outstanding_millions  core_cpi_excl._food_energy  \
# 288                            3113002.96                     235.961
# 289                            3133891.80                     236.185
# 290                            3150697.02                     236.625
# 291                            3173234.63                     237.072
# 292                            3192546.34                     237.529
# 293                            3209899.68                     237.837
# 294                            3231535.62                     238.195
# 295                            3248721.35                     238.405
# 296                            3265101.43                     238.786
# 297                            3275438.44                     239.191
# 298                            3283048.38                     239.458
# 299                            3309539.83                     239.584
#
#      all_loan_delinquency_rate_pct  personal_savings_rate_pct  \
# 288                           3.31                        5.2
# 289                            NaN                        5.3
# 290                            NaN                        5.2
# 291                           3.08                        5.4
# 292                            NaN                        5.6
# 293                            NaN                        5.6
# 294                           2.90                        5.5
# 295                            NaN                        5.3
# 296                            NaN                        5.5
# 297                           2.70                        5.4
# 298                            NaN                        5.6
# 299                            NaN                        6.0
#
#      consumer_sentiment_index
# 288                      81.2
# 289                      81.6
# 290                      80.0
# 291                      84.1
# 292                      81.9
# 293                      82.5
# 294                      81.8
# 295                      82.5
# 296                      84.6
# 297                      86.9
# 298                      88.8
# 299                      93.6

# %%
merged['business_loan_chargeoff_rate_pct'] = merged['business_loan_chargeoff_rate_pct'].ffill()
merged['all_loan_delinquency_rate_pct'] = merged['all_loan_delinquency_rate_pct'].ffill()

# %%
merged.tail(12)
# Out:
#      approval_year  approval_month  cpi_u_seasonality_adjusted  \
# 288           2014               1                     235.288
# 289           2014               2                     235.547
# 290           2014               3                     236.028
# 291           2014               4                     236.468
# 292           2014               5                     236.918
# 293           2014               6                     237.231
# 294           2014               7                     237.498
# 295           2014               8                     237.460
# 296           2014               9                     237.477
# 297           2014              10                     237.430
# 298           2014              11                     236.983
# 299           2014              12                     236.252
#
#      business_loan_chargeoff_rate_pct  commercial_bank_loans_leases_billions  \
# 288                              0.23                              1586.7954
# 289                              0.23                              1619.7096
# 290                              0.23                              1633.3176
# 291                              0.21                              1651.1911
# 292                              0.21                              1663.6926
# 293                              0.21                              1676.8043
# 294                              0.20                              1694.9147
# 295                              0.20                              1711.7561
# 296                              0.20                              1725.7351
# 297                              0.22                              1730.8096
# 298                              0.22                              1751.6656
# 299                              0.22                              1773.1780
#
#      consumer_credit_outstanding_millions  core_cpi_excl._food_energy  \
# 288                            3113002.96                     235.961
# 289                            3133891.80                     236.185
# 290                            3150697.02                     236.625
# 291                            3173234.63                     237.072
# 292                            3192546.34                     237.529
# 293                            3209899.68                     237.837
# 294                            3231535.62                     238.195
# 295                            3248721.35                     238.405
# 296                            3265101.43                     238.786
# 297                            3275438.44                     239.191
# 298                            3283048.38                     239.458
# 299                            3309539.83                     239.584
#
#      all_loan_delinquency_rate_pct  personal_savings_rate_pct  \
# 288                           3.31                        5.2
# 289                           3.31                        5.3
# 290                           3.31                        5.2
# 291                           3.08                        5.4
# 292                           3.08                        5.6
# 293                           3.08                        5.6
# 294                           2.90                        5.5
# 295                           2.90                        5.3
# 296                           2.90                        5.5
# 297                           2.70                        5.4
# 298                           2.70                        5.6
# 299                           2.70                        6.0
#
#      consumer_sentiment_index
# 288                      81.2
# 289                      81.6
# 290                      80.0
# 291                      84.1
# 292                      81.9
# 293                      82.5
# 294                      81.8
# 295                      82.5
# 296                      84.6
# 297                      86.9
# 298                      88.8
# 299                      93.6

# %%
# Save merged monthly macro table
merged.to_csv(OUT_PATH, index=False)
print('Saved:', OUT_PATH)
# Out:
# Saved: /Users/yangmar/Desktop/MS&E 246/Project/additional_dataset/more_macro/more_macro_merged_monthly.csv

# %%
sba = pd.read_csv("/Users/yangmar/Desktop/MS&E 246/Project/sba_loan_final_v1.csv")

res = sba.merge(merged, how = 'left', on=['approval_year','approval_month'])
# Out:
# /var/folders/y6/q6ynf7q94qv9p0n2wqdfnblc0000gn/T/ipykernel_57589/1790892376.py:1: DtypeWarning: Columns (0: DeliveryMethod, 1: ChargeOffDate, 2: NaicsSector) have mixed types. Specify dtype option on import or set low_memory=False.
#   sba = pd.read_csv("/Users/yangmar/Desktop/MS&E 246/Project/sba_loan_final_v1.csv")

# %%
res.head(10)
# Out:
#    BorrZip  CDC_Zip ThirdPartyLender_City ThirdPartyLender_State  \
# 0    66106    65109               UNKNOWN                UNKNOWN
# 1    92507    92106               UNKNOWN                UNKNOWN
# 2    46628    46601               UNKNOWN                UNKNOWN
# 3    62946    62704               UNKNOWN                UNKNOWN
# 4    84106    84109               UNKNOWN                UNKNOWN
# 5    84104    84109               UNKNOWN                UNKNOWN
# 6    43215    43215               UNKNOWN                UNKNOWN
# 7    45427    45402               UNKNOWN                UNKNOWN
# 8    23860    23805               UNKNOWN                UNKNOWN
# 9    54701    53716               UNKNOWN                UNKNOWN
#
#    ThirdPartyDollars  GrossApproval ApprovalDate  ApprovalFiscalYear  \
# 0                  0         166000   1990-01-02                1990
# 1                  0         117000   1990-01-02                1990
# 2                  0         261000   1990-01-03                1990
# 3                  0         262000   1990-01-03                1990
# 4                  0         154000   1990-01-03                1990
# 5                  0         135000   1990-01-03                1990
# 6                  0         300000   1990-01-03                1990
# 7                  0         284000   1990-01-04                1990
# 8                  0         479000   1990-01-05                1990
# 9                  0         750000   1990-01-05                1990
#
#   DeliveryMethod                                         subpgmdesc  \
# 0            504  Sec. 504 - Loan Guarantees - Private Sector Fi...
# 1            504  Sec. 504 - Loan Guarantees - Private Sector Fi...
# 2            504  Sec. 504 - Loan Guarantees - Private Sector Fi...
# 3            504  Sec. 504 - Loan Guarantees - Private Sector Fi...
# 4            504  Sec. 504 - Loan Guarantees - Private Sector Fi...
# 5            504  Sec. 504 - Loan Guarantees - Private Sector Fi...
# 6            504  Sec. 504 - Loan Guarantees - Private Sector Fi...
# 7            504  Sec. 504 - Loan Guarantees - Private Sector Fi...
# 8            504  Sec. 504 - Loan Guarantees - Private Sector Fi...
# 9            504  Sec. 504 - Loan Guarantees - Private Sector Fi...
#
#    TermInMonths  ProjectCounty ProjectState BusinessType LoanStatus  \
# 0            12      WYANDOTTE           KS   INDIVIDUAL        PIF
# 1           240      RIVERSIDE           CA   INDIVIDUAL        PIF
# 2           120      ST JOSEPH           IN  CORPORATION        PIF
# 3           240         SALINE           IL  CORPORATION     CHGOFF
# 4           240      SALT LAKE           UT  CORPORATION        PIF
# 5           240      SALT LAKE           UT  CORPORATION        PIF
# 6           240       FRANKLIN           OH  CORPORATION        PIF
# 7           240     MONTGOMERY           OH  CORPORATION        PIF
# 8           240  HOPEWELL CITY           VA  CORPORATION        PIF
# 9           240     EAU CLAIRE           WI  CORPORATION        PIF
#
#   ChargeOffDate  GrossChargeOffAmount  HasThirdParty NaicsSector  \
# 0           NaN                     0              0     UNKNOWN
# 1           NaN                     0              0     UNKNOWN
# 2           NaN                     0              0     UNKNOWN
# 3    2003-03-28                     0              0     UNKNOWN
# 4           NaN                     0              0     UNKNOWN
# 5           NaN                     0              0          51
# 6           NaN                     0              0     UNKNOWN
# 7           NaN                     0              0     UNKNOWN
# 8           NaN                     0              0          23
# 9           NaN                     0              0     UNKNOWN
#
#    BorrZip_clean  approval_year  approval_month  county_fips  CDC_Zip_clean  \
# 0          66106           1990               1      20209.0          65109
# 1          92507           1990               1       6065.0          92106
# 2          46628           1990               1      18141.0          46601
# 3          62946           1990               1      17165.0          62704
# 4          84106           1990               1      49035.0          84109
# 5          84104           1990               1      49035.0          84109
# 6          43215           1990               1      39049.0          43215
# 7          45427           1990               1      39113.0          45402
# 8          23860           1990               1      51670.0          23805
# 9          54701           1990               1      55035.0          53716
#
#    county_unemployment_rate  ten_year_treasury  one_year_treasury  \
# 0                       9.7           8.206667           7.920952
# 1                       5.4           8.206667           7.920952
# 2                       5.3           8.206667           7.920952
# 3                      10.9           8.206667           7.920952
# 4                       4.2           8.206667           7.920952
# 5                       4.2           8.206667           7.920952
# 6                       4.0           8.206667           7.920952
# 7                       6.0           8.206667           7.920952
# 8                       6.0           8.206667           7.920952
# 9                       4.6           8.206667           7.920952
#
#    mortgage_30y  crude_oil  dow_jones  fed_fund_rate  housing_starts   sp500  \
# 0         9.926      22.69    2590.54       8.229032          1551.0  329.08
# 1         9.926      22.69    2590.54       8.229032          1551.0  329.08
# 2         9.926      22.69    2590.54       8.229032          1551.0  329.08
# 3         9.926      22.69    2590.54       8.229032          1551.0  329.08
# 4         9.926      22.69    2590.54       8.229032          1551.0  329.08
# 5         9.926      22.69    2590.54       8.229032          1551.0  329.08
# 6         9.926      22.69    2590.54       8.229032          1551.0  329.08
# 7         9.926      22.69    2590.54       8.229032          1551.0  329.08
# 8         9.926      22.69    2590.54       8.229032          1551.0  329.08
# 9         9.926      22.69    2590.54       8.229032          1551.0  329.08
#
#    inflation_annual  cpi_u_seasonality_adjusted  \
# 0              6.11                       127.5
# 1              6.11                       127.5
# 2              6.11                       127.5
# 3              6.11                       127.5
# 4              6.11                       127.5
# 5              6.11                       127.5
# 6              6.11                       127.5
# 7              6.11                       127.5
# 8              6.11                       127.5
# 9              6.11                       127.5
#
#    business_loan_chargeoff_rate_pct  commercial_bank_loans_leases_billions  \
# 0                              1.41                               635.7875
# 1                              1.41                               635.7875
# 2                              1.41                               635.7875
# 3                              1.41                               635.7875
# 4                              1.41                               635.7875
# 5                              1.41                               635.7875
# 6                              1.41                               635.7875
# 7                              1.41                               635.7875
# 8                              1.41                               635.7875
# 9                              1.41                               635.7875
#
#    consumer_credit_outstanding_millions  core_cpi_excl._food_energy  \
# 0                             797714.86                       132.1
# 1                             797714.86                       132.1
# 2                             797714.86                       132.1
# 3                             797714.86                       132.1
# 4                             797714.86                       132.1
# 5                             797714.86                       132.1
# 6                             797714.86                       132.1
# 7                             797714.86                       132.1
# 8                             797714.86                       132.1
# 9                             797714.86                       132.1
#
#    all_loan_delinquency_rate_pct  personal_savings_rate_pct  \
# 0                           5.03                        7.9
# 1                           5.03                        7.9
# 2                           5.03                        7.9
# 3                           5.03                        7.9
# 4                           5.03                        7.9
# 5                           5.03                        7.9
# 6                           5.03                        7.9
# 7                           5.03                        7.9
# 8                           5.03                        7.9
# 9                           5.03                        7.9
#
#    consumer_sentiment_index
# 0                      93.0
# 1                      93.0
# 2                      93.0
# 3                      93.0
# 4                      93.0
# 5                      93.0
# 6                      93.0
# 7                      93.0
# 8                      93.0
# 9                      93.0

# %%
res.isnull().sum()[-10:]
# Out:
# sp500                                    0
# inflation_annual                         0
# cpi_u_seasonality_adjusted               0
# business_loan_chargeoff_rate_pct         0
# commercial_bank_loans_leases_billions    0
# consumer_credit_outstanding_millions     0
# core_cpi_excl._food_energy               0
# all_loan_delinquency_rate_pct            0
# personal_savings_rate_pct                0
# consumer_sentiment_index                 0
# dtype: int64

# %%
res.to_csv('/Users/yangmar/Desktop/MS&E 246/Project/sba_loan_final_v2.csv', index=False)
